# %%
import pandas as pd
from nltk.corpus import stopwords
from nlpgraph import generate_word_graph_from_dataset

exclude_terms = set(stopwords.words('portuguese'))
df = pd.read_csv("tupi_hierarchy.csv")

# Example usage:
generate_word_graph_from_dataset(df,"political", exclude_terms, 50, "#FDD870")
